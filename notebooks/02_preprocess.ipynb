# %% [markdown]
# ## Pré processamento dos dados

# %% [markdown]
# - Importando os pacotes presentes em src.

# %%
import src.config as config
from src.data_io import load_raw, save_csv
from src.pipeline_preprocessing import build_processed_datasets
import os

# %% [markdown]
# - Carregando os dados brutos.

# %%
df_raw = load_raw(config.RAW_PATH)

# %% [markdown]
# - Processando os dados brutos e aplicando as correções e regularizações.

# %%
datasets, scalers = build_processed_datasets(df_raw, config)

# %% [markdown]
# - Salvando os dados pré-processados em datasets específicos.

# %%
os.makedirs(config.PROCESSED_DIR, exist_ok=True)

save_csv(datasets["risk"], f"{config.PROCESSED_DIR}/creditcard_risk_zscore.csv")
save_csv(datasets["credit"], f"{config.PROCESSED_DIR}/creditcard_credit_behavior_zscore.csv")
save_csv(datasets["consumption"], f"{config.PROCESSED_DIR}/creditcard_consumption_zscore.csv")
save_csv(datasets["full"], f"{config.PROCESSED_DIR}/creditcard_full_zscore.csv")
